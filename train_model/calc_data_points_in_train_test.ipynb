# %%
import pandas as pd

# %%
train_df = pd.read_csv('train.csv')
train_df
# Out:
#                                               file_name        IA        IC  \
# 0      031064763a753380d14b0526a0208858_Bus 1 _event N1 -0.432270  0.744279
# 1      031064763a753380d14b0526a0208858_Bus 1 _event N1 -0.294195  0.716700
# 2      031064763a753380d14b0526a0208858_Bus 1 _event N1 -0.110095  0.606384
# 3      031064763a753380d14b0526a0208858_Bus 1 _event N1  0.000365  0.597191
# 4      031064763a753380d14b0526a0208858_Bus 1 _event N1  0.147645  0.560419
# ...                                                 ...       ...       ...
# 64427  fd5b82241fce8822cd0a75c15d371c11_Bus 2 _event N1 -0.691711  0.210535
# 64428  fd5b82241fce8822cd0a75c15d371c11_Bus 2 _event N1 -0.737776  0.329927
# 64429  fd5b82241fce8822cd0a75c15d371c11_Bus 2 _event N1 -0.728563  0.403399
# 64430  fd5b82241fce8822cd0a75c15d371c11_Bus 2 _event N1 -0.562729  0.430951
# 64431  fd5b82241fce8822cd0a75c15d371c11_Bus 2 _event N1 -0.516664  0.541159
#
# ...

# %%
train_df['target'] = 0
train_df['target'][train_df['abnorm_evnt'] == 1] = 1
train_df['target'][train_df['emerg_evnt'] == 1] = 2
# Out:
# /tmp/ipykernel_264819/3041582622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['target'][train_df['abnorm_evnt'] == 1] = 1
# /tmp/ipykernel_264819/3041582622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['target'][train_df['emerg_evnt'] == 1] = 2

# %%
len(train_df[train_df['target'] == 0])
# Out:
# 52531

# %%
len(train_df[train_df['target'] == 1])
# Out:
# 10268

# %%
len(train_df[train_df['target'] == 2])
# Out:
# 1633

# %%
1633 / 64432
# Out:
# 0.02534454929227713

# %%
eval_df = pd.read_csv('test.csv')
eval_df
# Out:
#                                               file_name        IA        IC  \
# 0      4d8cbe560afd5f7f50ee476b9651f95d_Bus 1 _event N1  0.690740 -0.037126
# 1      4d8cbe560afd5f7f50ee476b9651f95d_Bus 1 _event N1  0.911660 -0.220986
# 2      4d8cbe560afd5f7f50ee476b9651f95d_Bus 1 _event N1  1.058940 -0.404846
# 3      4d8cbe560afd5f7f50ee476b9651f95d_Bus 1 _event N1  1.095760 -0.505969
# 4      4d8cbe560afd5f7f50ee476b9651f95d_Bus 1 _event N1  0.930070 -0.524355
# ...                                                 ...       ...       ...
# 17721  f4490a5f77f71092662b50412e3a2e3f_Bus 2 _event N2  0.008477 -0.000697
# 17722  f4490a5f77f71092662b50412e3a2e3f_Bus 2 _event N2 -0.009949 -0.000697
# 17723  f4490a5f77f71092662b50412e3a2e3f_Bus 2 _event N2 -0.000736  0.008487
# 17724  f4490a5f77f71092662b50412e3a2e3f_Bus 2 _event N2  0.017690 -0.000697
# 17725  f4490a5f77f71092662b50412e3a2e3f_Bus 2 _event N2  0.017690  0.008487
#
# ...

# %%
eval_df['target'] = 0
eval_df['target'][eval_df['abnorm_evnt'] == 1] = 1
eval_df['target'][eval_df['emerg_evnt'] == 1] = 2
# Out:
# /tmp/ipykernel_264819/2441780070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df['target'][eval_df['abnorm_evnt'] == 1] = 1
# /tmp/ipykernel_264819/2441780070.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df['target'][eval_df['emerg_evnt'] == 1] = 2

# %%
len(eval_df[eval_df['target'] == 0])
# Out:
# 11937

# %%
len(eval_df[eval_df['target'] == 1])
# Out:
# 5521

# %%
len(eval_df[eval_df['target'] == 2])
# Out:
# 268

# %%
268 / 17726
# Out:
# 0.01511903418706984

# %%
test_df = pd.read_csv('unlabeled.csv')
test_df
# Out:
#                                      file_name        IA        IC      UA BB  \
# 0       0151603efd7d68da8f18141591f7f252_Bus 1  0.755175 -0.744987  64.195877
# 1       0151603efd7d68da8f18141591f7f252_Bus 1  0.819610 -0.956426  50.323280
# 2       0151603efd7d68da8f18141591f7f252_Bus 1  0.801200 -1.195444  34.749634
# 3       0151603efd7d68da8f18141591f7f252_Bus 1  0.745970 -1.333339  20.398100
# 4       0151603efd7d68da8f18141591f7f252_Bus 1  0.598690 -1.259795   5.385965
# ...                                        ...       ...       ...        ...
# 346227  ffcacf44cae74848751247458c0c039d_Bus 2  0.109820 -0.074169  72.121559
# 346228  ffcacf44cae74848751247458c0c039d_Bus 2  0.100607 -0.064985  61.324017
# 346229  ffcacf44cae74848751247458c0c039d_Bus 2  0.100607 -0.101721  46.795216
# 346230  ffcacf44cae74848751247458c0c039d_Bus 2  0.091394 -0.101721  32.134338
# 346231  ffcacf44cae74848751247458c0c039d_Bus 2  0.045329 -0.092537  17.968758
#
# ...

# %%
test_df['target'] = 0
test_df['target'][test_df['abnorm_evnt'] == 1] = 1
test_df['target'][test_df['emerg_evnt'] == 1] = 2
# Out:
# /tmp/ipykernel_264819/2994226140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['target'][test_df['abnorm_evnt'] == 1] = 1
# /tmp/ipykernel_264819/2994226140.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['target'][test_df['emerg_evnt'] == 1] = 2

# %%
len(test_df[test_df['target'] == 0])
# Out:
# 327007

# %%
len(test_df[test_df['target'] == 1])
# Out:
# 12783

# %%
len(test_df[test_df['target'] == 2])
# Out:
# 6442

# %%
6442 / 346232
# Out:
# 0.018606021396058135
